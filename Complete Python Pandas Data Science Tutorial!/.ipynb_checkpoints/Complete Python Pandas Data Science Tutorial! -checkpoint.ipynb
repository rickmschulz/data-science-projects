# %% [markdown]
# # Loading Data into Pandas

# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

# %% [markdown]
# # Reading Data in Pandas

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# # Making Changes to the Data

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)

# x = list(df.columns.values)
cols = df.columns.values.tolist()
df = df[cols[:4] + [cols[-1]] + cols[4:12]]

# %% [markdown]
# # Filtering Data

# %%
import re

# df = df.loc[~df['Name'].str.contains('mega', flags=re.I, regex=True)]

df = df.loc[(df['Generation'] < 5) & (df['Legendary'] == False) & 
           (~df['Name'].str.contains('mega', flags=re.I, regex=True))]

df.to_csv('filtered.csv', sep=';', index=False)


poke_type = 'Electric'
new_df_filter = df.loc[((df['Attack'] > 90) | (df['Sp. Atk'] > 90)) & 
                       ((df['Type 1'] == poke_type) | (df['Type 2'] == poke_type))]


new_df_filter.reset_index(drop=True, inplace=True)

new_df_filter.to_csv('filtered_types.csv', sep=';', index=False)

new_df_filter.sort_values(by=['Sp. Atk'], ascending=False)
# Out:
#       #              Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 7   462         Magnezone  Electric   Steel    535  70      70      115
# 1    82          Magneton  Electric   Steel    465  50      60       95
# 4   181          Ampharos  Electric     NaN    510  90      75       85
# 3   135           Jolteon  Electric     NaN    525  65      65       60
# 5   310         Manectric  Electric     NaN    475  70      75       60
# 10  479   RotomHeat Rotom  Electric    Fire    520  50      65      107
# 11  479   RotomWash Rotom  Electric   Water    520  50      65      107
# 12  479  RotomFrost Rotom  Electric     Ice    520  50      65      107
# 13  479    RotomFan Rotom  Electric  Flying    520  50      65      107
# 14  479    RotomMow Rotom  Electric   Grass    520  50      65      107
# 0    81         Magnemite  Electric   Steel    325  25      35       70
# 2   125        Electabuzz  Electric     NaN    490  65      83       57
# 6   405            Luxray  Electric     NaN    523  80     120       79
# 8   466        Electivire  Electric     NaN    540  75     123       67
# 9   479             Rotom  Electric   Ghost    440  50      50       77
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7       130       90     60           4      False
# 1       120       70     70           1      False
# 4       115       90     55           2      False
# 3       110       95    130           1      False
# 5       105       60    105           3      False
# 10      105      107     86           4      False
# 11      105      107     86           4      False
# 12      105      107     86           4      False
# 13      105      107     86           4      False
# 14      105      107     86           4      False
# 0        95       55     45           1      False
# 2        95       85    105           1      False
# 6        95       79     70           4      False
# 8        95       85     95           4      False
# 9        95       77     91           4      False

# %% [markdown]
# # Changing Data with Conditional Changes

# %%
df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True
df
# Out:
#        #            Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1       Bulbasaur     Grass  Poison    318   45      49       49
# 1      2         Ivysaur     Grass  Poison    405   60      62       63
# 2      3        Venusaur     Grass  Poison    525   80      82       83
# 4      4      Charmander      Fire     NaN    309   39      52       43
# 5      5      Charmeleon      Fire     NaN    405   58      64       58
# ..   ...             ...       ...     ...    ...  ...     ...      ...
# 535  479  RotomFan Rotom  Electric  Flying    520   50      65      107
# 536  479  RotomMow Rotom  Electric   Grass    520   50      65      107
# 546  488       Cresselia   Psychic     NaN    600  120      70      120
# 547  489          Phione     Water     NaN    480   80      80       80
# 548  490         Manaphy     Water     NaN    600  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 4         60       50     65           1       True
# 5         80       65     80           1       True
# ..       ...      ...    ...         ...        ...
# 535      105      107     86           4      False
# 536      105      107     86           4      False
# 546       75      130     85           4      False
# 547       80       80     80           4      False
# 548      100      100    100           4      False
#
# [468 rows x 13 columns]

# %% [markdown]
# # Agregate Statistics (GroupBy)

# %%
df = pd.read_csv('filtered.csv', delimiter=';')

# df.groupby(['Type 1']).mean().sort_values('Sp. Atk', ascending=False)

df.groupby(['Type 1']).count()['#'].sort_values(ascending=False)

# df.groupby(['Type 1', 'Type 2']).count()['#'].sort_values(ascending=False)
# Out:
# Type 1
# Water       80
# Normal      70
# Grass       44
# Bug         43
# Electric    29
# Fire        27
# Rock        26
# Poison      24
# Psychic     24
# Ground      20
# Fighting    15
# Ghost       13
# Ice         13
# Dark        11
# Steel       11
# Dragon      10
# Fairy        8
# Name: #, dtype: int64

# %% [markdown]
# # Working with Large Amounts of Data

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('filtered.csv', delimiter=';', chunksize=5):
    results = df
    
    new_df = pd.concat([new_df, results])
    
new_df
# Out:
#        #       Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 465  488  Cresselia  Psychic     NaN    600  120      70      120       75
# 466  489     Phione    Water     NaN    480   80      80       80       80
# 467  490    Manaphy    Water     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# 465      130     85           4      False
# 466       80     80           4      False
# 467      100    100           4      False
